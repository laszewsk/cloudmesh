# %%
import cloudmesh

# %%
config = cloudmesh.cm_config_server("~/.futuregrid/cloudmesh.yaml")

# %%
clouds = config["cloudmesh"]["clouds"].keys()

# %%
print clouds
# Out:
# ['india_openstack_essex', 'india-eucalyptus', 'sierra_openstack_grizzly']

# %%
print cloudmesh.config.cm_config.cm_config()
# Out:
# {
#     "kind": "user",
#     "filename": "/Users/neu/.futuregrid/cloudmesh.yaml",
#     "location": "/Users/neu/.futuregrid/cloudmesh.yaml",
#     "cloudmesh": {
#         "profile": {
#             "username": "gvonlasz",
#             "uid": "10014",
#             "firstname": "Gregor",
#             "lastname": "von Laszewski",
#             "e_mail": "laszewski@gmail.com",
#             "phone": "812 856 1311",
#             "gid": "100",
#             "address": [
#                 "PTI",
#                 "here and there"
#             ]
#         },
#         "index": 119,
#         "clouds": {
#             "india_openstack_essex": {
#                 "cm_heading": "India Openstack, Essex",
#                 "cm_label": "ios",
#                 "cm_host": "india.futuregrid.org",
#                 "default": {
#                     "project": "fg82",
#                     "flavor": "m1.tiny",
#                     "image": "717d1dc8-3ed4-4758-9678-8f6421e1fbf2"
# ...

# %%
print cloudmesh.cm_config()
# Out:
# {
#     "kind": "user",
#     "filename": "/Users/neu/.futuregrid/cloudmesh.yaml",
#     "location": "/Users/neu/.futuregrid/cloudmesh.yaml",
#     "cloudmesh": {
#         "profile": {
#             "username": "gvonlasz",
#             "uid": "10014",
#             "firstname": "Gregor",
#             "lastname": "von Laszewski",
#             "e_mail": "laszewski@gmail.com",
#             "phone": "812 856 1311",
#             "gid": "100",
#             "address": [
#                 "PTI",
#                 "here and there"
#             ]
#         },
#         "index": 119,
#         "clouds": {
#             "india_openstack_essex": {
#                 "cm_heading": "India Openstack, Essex",
#                 "cm_label": "ios",
#                 "cm_host": "india.futuregrid.org",
#                 "default": {
#                     "project": "fg82",
#                     "flavor": "m1.tiny",
#                     "image": "717d1dc8-3ed4-4758-9678-8f6421e1fbf2"
# ...

# %%
print cloudmesh.UserLoad()
# Out:
# {
#     "kind": "user",
#     "filename": "/Users/neu/.futuregrid/cloudmesh.yaml",
#     "location": "/Users/neu/.futuregrid/cloudmesh.yaml",
#     "cloudmesh": {
#         "profile": {
#             "username": "gvonlasz",
#             "uid": "10014",
#             "firstname": "Gregor",
#             "lastname": "von Laszewski",
#             "e_mail": "laszewski@gmail.com",
#             "phone": "812 856 1311",
#             "gid": "100",
#             "address": [
#                 "PTI",
#                 "here and there"
#             ]
#         },
#         "index": 119,
#         "clouds": {
#             "india_openstack_essex": {
#                 "cm_heading": "India Openstack, Essex",
#                 "cm_label": "ios",
#                 "cm_host": "india.futuregrid.org",
#                 "default": {
#                     "project": "fg82",
#                     "flavor": "m1.tiny",
#                     "image": "717d1dc8-3ed4-4758-9678-8f6421e1fbf2"
# ...
